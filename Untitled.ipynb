# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
path = "./experiment_data/"

# %%
def do_plot(datatype):
    path = "./experiment_data/"
    exps = ["SGD_small", "SP2l1_small", "SP2l2_small", "SP2max_small"]

    for exp in exps:
        data_file = path + exp + "/" + datatype + ".pkl"
        data = pickle.load( open(data_file, "rb" ) )
        plt.plot(data, label=exp)

    plt.ylabel(datatype)
    plt.legend()
    plt.show()

# %%
do_plot("test_losses")

# %%
do_plot("train_losses")

# %%
do_plot("test_class_accs")

# %%
do_plot("train_class_accs")
